# %%
from pathlib import Path

md_text = Path("files/coffee_shops_sf.md").read_text(encoding="utf-8")
print(md_text[:500])  # preview first 500 chars
# Out:
# # San Francisco Coffee Shops Research
#
# ## Top Coffee Shops in San Francisco
#
# ### Blue Bottle Coffee
# - **Founded**: 2002 in Oakland, expanded to SF
# - **Specialty**: Single-origin coffee, pour-over methods
# - **Notable**: Known for freshly roasted beans, minimalist aesthetic
# - **Locations**: Multiple SF locations including Ferry Building
#
# ### Philz Coffee
# - **Founded**: 2003 in San Francisco
# - **Specialty**: Custom blended coffee, personalized service
# - **Notable**: Founded by Phil Jaber, known for

# %%
import uuid
from typing import TypedDict, List
from langgraph.graph import StateGraph, START, END
from pydantic import BaseModel, Field
from langchain.chat_models import init_chat_model

# %%
# Initialize Model
model = init_chat_model("google_genai:models/gemini-2.5-flash-lite")

# --- 1. TypedDicts (The Internal Memory) ---
class Checkpoint(TypedDict):
    id: str
    name: str
    objective: str  # Matches Pydantic field below
    study_material: str
    quiz_questions: list[str]

class State(TypedDict):
    report: str
    checkpoints: list[Checkpoint]

# --- 2. Pydantic Models (The LLM Interface) ---
class CheckpointItem(BaseModel):
    name: str = Field(description="The name of the checkpoint")
    objective: str = Field(description="the specific objective of the checkpoint") # FIXED: typo 'objetive' -> 'objective'

class CheckpointResponse(BaseModel):
    checkpoints: List[CheckpointItem]

class CheckpointContent(BaseModel):
    study_material: str = Field(description="Brief study material (approx 100 words)")
    quiz_questions: List[str] = Field(description="Exactly 3 assessment questions")

# Setup LLM
model_with_structured_output = model.with_structured_output(CheckpointResponse)
content_gen=model.with_structured_output(CheckpointContent)

# %%
# --- 3. The Node ---
def generate(state: State):
    report = state['report']
    
    # Fixed variable name spelling
    response = model_with_structured_output.invoke(f"extract and breakdown this report {report} into learning checkpoints")
    
    clean_checkpoints = []
    for item in response.checkpoints:
        data = item.model_dump()
        
        # Inject ID
        data['id'] = str(uuid.uuid4())
        
        clean_checkpoints.append(data)
    
    # FIXED: Key must match State definition exactly ("checkpoints")
    return {"checkpoints": clean_checkpoints} 

# --- 4. Build Graph ---
builder = StateGraph(State)
builder.add_node("generate", generate)
builder.add_edge(START, "generate")
builder.add_edge("generate", END)

graph = builder.compile()

# --- 5. Run ---
# Define the variable first
# report_var = "This is a report about learning Python." 
result = graph.invoke({"report": md_text})

print(result)
# Out:
# {'report': '# San Francisco Coffee Shops Research\n\n## Top Coffee Shops in San Francisco\n\n### Blue Bottle Coffee\n- **Founded**: 2002 in Oakland, expanded to SF\n- **Specialty**: Single-origin coffee, pour-over methods\n- **Notable**: Known for freshly roasted beans, minimalist aesthetic\n- **Locations**: Multiple SF locations including Ferry Building\n\n### Philz Coffee\n- **Founded**: 2003 in San Francisco\n- **Specialty**: Custom blended coffee, personalized service\n- **Notable**: Founded by Phil Jaber, known for unique blends like "Tesora"\n- **Locations**: Original location in Mission District, now citywide\n\n### Sightglass Coffee\n- **Founded**: 2009\n- **Specialty**: Third-wave coffee, roasting transparency\n- **Notable**: Large roastery with viewing windows, industrial aesthetic\n- **Location**: SOMA district flagship location\n\n### Ritual Coffee Roasters\n- **Founded**: 2005\n- **Specialty**: Direct trade relationships, seasonal offerings\n- **Notable**: Pioneer in San Francisco\'s third-wave coffee movement\n- **Locations**: Multiple locations including Castro and Mission\n\n### Four Barrel Coffee\n- **Founded**: 2008\n- **Specialty**: Small-batch roasting, community focus\n- **Notable**: Known for Valencia Street location, local institution\n- **Location**: Mission District', 'checkpoints': [{'name': 'Blue Bottle Coffee', 'objective': 'Research the founding, specialty, notable features, and locations of Blue Bottle Coffee in San Francisco.', 'id': '8d6eb287-81ef-4836-9ef7-c5c1387c06bf'}, {'name': 'Philz Coffee', 'objective': 'Research the founding, specialty, notable features, and locations of Philz Coffee in San Francisco.', 'id': 'ba9bd658-f955-4deb-9aea-4fba4f804587'}, {'name': 'Sightglass Coffee', 'objective': 'Research the founding, specialty, notable features, and locations of Sightglass Coffee in San Francisco.', 'id': 'ececdf77-7f7b-4180-b97c-0bd7799dd8d1'}, {'name': 'Ritual Coffee Roasters', 'objective': 'Research the founding, specialty, notable features, and locations of Ritual Coffee Roasters in San Francisco.', 'id': '2d007320-4ee1-4ab7-9690-0b1075161b97'}, {'name': 'Four Barrel Coffee', 'objective': 'Research the founding, specialty, notable features, and locations of Four Barrel Coffee in San Francisco.', 'id': 'd30174ad-581f-4225-978f-84f0ccae809a'}]}

# %%
result
# Out:
# {'report': '# San Francisco Coffee Shops Research\n\n## Top Coffee Shops in San Francisco\n\n### Blue Bottle Coffee\n- **Founded**: 2002 in Oakland, expanded to SF\n- **Specialty**: Single-origin coffee, pour-over methods\n- **Notable**: Known for freshly roasted beans, minimalist aesthetic\n- **Locations**: Multiple SF locations including Ferry Building\n\n### Philz Coffee\n- **Founded**: 2003 in San Francisco\n- **Specialty**: Custom blended coffee, personalized service\n- **Notable**: Founded by Phil Jaber, known for unique blends like "Tesora"\n- **Locations**: Original location in Mission District, now citywide\n\n### Sightglass Coffee\n- **Founded**: 2009\n- **Specialty**: Third-wave coffee, roasting transparency\n- **Notable**: Large roastery with viewing windows, industrial aesthetic\n- **Location**: SOMA district flagship location\n\n### Ritual Coffee Roasters\n- **Founded**: 2005\n- **Specialty**: Direct trade relationships, seasonal offerings\n- **Notable**: Pioneer in San Francisco\'s third-wave coffee movement\n- **Locations**: Multiple locations including Castro and Mission\n\n### Four Barrel Coffee\n- **Founded**: 2008\n- **Specialty**: Small-batch roasting, community focus\n- **Notable**: Known for Valencia Street location, local institution\n- **Location**: Mission District',
#  'checkpoints': [{'name': 'Blue Bottle Coffee',
#    'objective': 'Research the founding, specialty, notable features, and locations of Blue Bottle Coffee in San Francisco.',
#    'id': '8d6eb287-81ef-4836-9ef7-c5c1387c06bf'},
#   {'name': 'Philz Coffee',
#    'objective': 'Research the founding, specialty, notable features, and locations of Philz Coffee in San Francisco.',
#    'id': 'ba9bd658-f955-4deb-9aea-4fba4f804587'},
#   {'name': 'Sightglass Coffee',
#    'objective': 'Research the founding, specialty, notable features, and locations of Sightglass Coffee in San Francisco.',
#    'id': 'ececdf77-7f7b-4180-b97c-0bd7799dd8d1'},
#   {'name': 'Ritual Coffee Roasters',
#    'objective': 'Research the founding, specialty, notable features, and locations of Ritual Coffee Roasters in San Francisco.',
#    'id': '2d007320-4ee1-4ab7-9690-0b1075161b97'},
#   {'name': 'Four Barrel Coffee',
#    'objective': 'Research the founding, specialty, notable features, and locations of Four Barrel Coffee in San Francisco.',
#    'id': 'd30174ad-581f-4225-978f-84f0ccae809a'}]}

# %%
# Out:
# content="Parrots have colorful feathers for a variety of reasons, and it's a fascinating interplay of **evolution, communication, and survival**. Here's a breakdown of the main drivers behind their vibrant plumage:\n\n**1. Communication and Social Signaling:**\n\n*   **Mate Attraction:** This is arguably the most significant reason. Brighter, more elaborate, and healthier-looking feathers can signal a parrot's fitness and desirability to potential mates. Males, in particular, often display more vibrant colors to attract females. Think of it like a peacock's tail – a visual advertisement of genetic quality.\n*   **Species Recognition:** In dense rainforests where visibility can be limited, distinct color patterns help parrots identify members of their own species. This is crucial for flocking, mating, and avoiding hybridization. Imagine trying to find your family in a crowded marketplace without distinct clothing – colors serve a similar purpose.\n*   **Social Status and Dominance:** Within a flock, subtle variations in color intensity or specific feather patterns might be used to signal dominance or social hierarchy. This can help reduce aggression and maintain order within the group.\n*   **Emotional State:** While not as pronounced as in some other birds, changes in feather ruffling or slight color shifts can sometimes indicate a parrot's mood, such as excitement, stress, or aggression.\n\n**2. Camouflage (Counterintuitive but True!):**\n\n*   **Blinding in Sunlight:** While seemingly bright, the vibrant colors can actually help parrots blend into the dappled light of their tropical habitats. The greens, blues, and reds can mimic the colors of leaves, fruits, and flowers, making them harder for predators to spot.\n*   **Disruptive Coloration:** The patches of different colors can break up the parrot's outline, making it difficult for predators to perceive them as a single, cohesive shape.\n\n**3. Diet and Health:**\n\n*   **Pigment Production:** Many of the vibrant colors in parrot feathers are derived from pigments produced by the parrot itself, such as carotenoids. These pigments are obtained from their diet of fruits, seeds, and flowers. Therefore, the richness and intensity of their colors can be an indicator of their diet and overall health. A dull or faded color might suggest a deficiency or illness.\n\n**4. Thermoregulation (Less Significant, but Possible):**\n\n*   **Heat Absorption/Reflection:** While not a primary driver, dark colors can absorb more heat, which might be beneficial in cooler environments or during cold nights. Conversely, lighter colors might reflect sunlight, helping to prevent overheating in very hot climates. However, parrots often have other more effective mechanisms for thermoregulation.\n\n**5. Melanin and Structural Colors:**\n\n*   **Melanin:** This pigment is responsible for black, brown, and some shades of gray and red. It's deposited into the feather structure.\n*   **Carotenoids:** These are obtained from the diet and produce yellows, oranges, and reds.\n*   **Structural Colors:** Blues and greens are often not due to pigments but to the way light interacts with the microscopic structure of the feather barbules. This is called iridescence or structural coloration. The arrangement of keratin and air within the feather scatters light, producing these brilliant hues.\n\n**In summary, parrot coloration is a multi-faceted evolutionary adaptation.** It's a complex language of visual signals that helps them find mates, recognize their own kind, navigate their environment, and even communicate their well-being. The sheer diversity of colors and patterns across different parrot species reflects the various selective pressures they've faced in their unique ecological niches." additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019ba7ea-9d38-7903-a4a7-7fe1481af6fd-0' tool_calls=[] ...
# content="Airplanes fly due to a brilliant interplay of physics, primarily governed by **four fundamental forces**:\n\n1.  **Lift:** This is the upward force that counteracts gravity and keeps the airplane in the air. It's generated by the wings.\n2.  **Weight (or Gravity):** This is the downward force pulling the airplane towards the Earth, caused by its mass.\n3.  **Thrust:** This is the forward force that propels the airplane through the air, overcoming drag. It's generated by the engines.\n4.  **Drag:** This is the backward force that opposes the airplane's motion, caused by air resistance.\n\nFor an airplane to fly, **lift must be greater than or equal to weight**, and **thrust must be greater than or equal to drag**.\n\nLet's break down how lift is generated, as it's the most complex and crucial element:\n\n### The Magic of the Wings (Airfoil Shape)\n\nThe key to lift lies in the **shape of the airplane's wings**, known as an **airfoil**. An airfoil is typically curved on the top and flatter on the bottom.\n\nHere's how this shape, combined with the airplane's forward motion, creates lift:\n\n*   **Bernoulli's Principle:** As the airplane moves forward (thanks to thrust), air flows over and under the wings. Because the top surface of the wing is curved, the air traveling over it has to travel a longer distance than the air traveling under the flatter bottom surface in the same amount of time.\n    *   To cover the longer distance in the same time, the air flowing over the top of the wing must move **faster** than the air flowing under the bottom.\n    *   According to Bernoulli's principle, where a fluid (like air) moves faster, its pressure is lower.\n    *   Therefore, the air pressure above the wing is **lower** than the air pressure below the wing.\n\n*   **Pressure Difference = Lift:** This difference in pressure creates an upward force. The higher pressure beneath the wing pushes upwards more strongly than the lower pressure above the wing pushes downwards. This net upward force is **lift**.\n\n*   **Angle of Attack:** The angle at which the wing meets the oncoming air, called the **angle of attack**, also plays a significant role.\n    *   A slight upward angle of attack further forces the air to travel a longer path over the top of the wing, increasing the speed difference and thus the lift.\n    *   However, if the angle of attack becomes too steep, the airflow over the top of the wing can separate, causing a stall and a dramatic loss of lift.\n\n### The Role of Other Forces\n\n*   **Thrust:** The engines (jet engines or propellers) are responsible for generating thrust. They do this by expelling air or exhaust gases backward at high speed, which, according to Newton's third law of motion (for every action, there is an equal and opposite reaction), pushes the airplane forward.\n\n*   **Drag:** As the airplane moves through the air, it encounters resistance. This is drag. There are two main types:\n    *   **Parasitic Drag:** This includes form drag (due to the shape of the airplane) and skin friction drag (due to the air rubbing against the airplane's surfaces). Streamlined designs minimize this.\n    *   **Induced Drag:** This is a byproduct of generating lift. It's related to the wingtip vortices that form as air spills from the high-pressure area below the wing to the low-pressure area above.\n\n*   **Weight:** This is simply the force of gravity acting on the airplane's mass. To stay airborne, lift must overcome this force.\n\n### Putting It All Together\n\n1.  **Engines generate Thrust:** This propels the airplane forward.\n2.  **Forward motion creates airflow over the wings:** This airflow is crucial for generating lift.\n3.  **The airfoil shape of the wings causes the air to move faster over the top:** This results in lower pressure above the wing and higher pressure below.\n4.  **The pressure difference creates Lift:** This upward force counteracts the downward force of Weight.\n5.  **If Lift > Weight, th ...
# content="Quantum computing is a revolutionary new type of computing that harnesses the principles of **quantum mechanics** to perform calculations. Unlike classical computers that store information as bits representing either a 0 or a 1, quantum computers use **qubits**.\n\nHere's a breakdown of the key concepts:\n\n**1. Qubits: The Building Blocks of Quantum Computing**\n\n*   **Superposition:** This is the most fundamental difference. A qubit can represent not just a 0 or a 1, but also a **combination of both 0 and 1 simultaneously**. Imagine a spinning coin that is neither heads nor tails until it lands. This allows a quantum computer to explore many possibilities at once.\n*   **Entanglement:** This is another bizarre but powerful quantum phenomenon. When qubits are entangled, they become interconnected in such a way that the state of one qubit is instantly correlated with the state of another, regardless of the distance between them. Measuring one entangled qubit instantaneously influences the other. This allows for complex correlations and parallel processing that are impossible with classical bits.\n\n**2. How Quantum Computers Work (in a simplified way)**\n\nInstead of manipulating bits with logic gates, quantum computers use **quantum gates** that operate on qubits. These gates manipulate the superposition and entanglement of qubits to perform calculations.\n\nThe process generally involves:\n\n*   **Initialization:** Setting up qubits in a specific initial state.\n*   **Quantum Operations:** Applying a sequence of quantum gates to manipulate the qubits. This is where the quantum algorithms come into play.\n*   **Measurement:** Observing the final state of the qubits. Due to the probabilistic nature of quantum mechanics, the measurement collapses the superposition into a definite 0 or 1. This is why quantum algorithms are designed to increase the probability of measuring the correct answer.\n\n**3. Why is Quantum Computing Important? What Can it Do?**\n\nQuantum computers are not meant to replace classical computers for everyday tasks like browsing the internet or writing documents. Instead, they excel at solving specific types of problems that are **intractable for even the most powerful classical supercomputers**. These problems often involve:\n\n*   **Drug Discovery and Materials Science:** Simulating the behavior of molecules and materials at the atomic level to design new drugs, catalysts, and advanced materials with unprecedented properties.\n*   **Optimization Problems:** Finding the best possible solution from a vast number of possibilities. This could be applied to logistics, financial modeling, traffic management, and more.\n*   **Cryptography:** Breaking current encryption methods (like RSA) by efficiently factoring large numbers, but also enabling new, quantum-resistant encryption.\n*   **Artificial Intelligence and Machine Learning:** Developing more powerful and efficient AI algorithms, particularly for complex pattern recognition and data analysis.\n*   **Scientific Research:** Advancing our understanding of fundamental physics, cosmology, and other scientific disciplines.\n\n**4. Current State and Challenges**\n\nQuantum computing is still in its early stages of development. While significant progress has been made, there are still major challenges:\n\n*   **Decoherence:** Qubits are very fragile and can easily lose their quantum properties due to environmental noise (heat, vibrations, electromagnetic fields). Maintaining their coherence for long enough to perform complex calculations is a major hurdle.\n*   **Error Correction:** Quantum computers are prone to errors. Developing robust quantum error correction techniques is crucial for building reliable machines.\n*   **Scalability:** Building quantum computers with a large number of stable and interconnected qubits is extremely difficult.\n*   **Algorithm Development:** Creating new quantum algorithms that can effectively leverage the power of quantum ...

# %%
import uuid
from typing import TypedDict, List
from langgraph.graph import StateGraph, START, END
from pydantic import BaseModel, Field
from langchain.chat_models import init_chat_model

# Initialize Model
model = init_chat_model("google_genai:models/gemini-flash-latest")

# --- 1. STATE DEFINITIONS ---
class Checkpoint(TypedDict):
    id: str
    name: str
    objective: str
    study_material: str 
    quiz_questions: list[str]

class State(TypedDict):
    report: str
    user_request: str
    checkpoints: list[Checkpoint]

# --- 2. PYDANTIC MODELS ---

# For Node 1
class CheckpointItem(BaseModel):
    name: str = Field(description="Name of the checkpoint")
    objective: str = Field(description="Objective of the checkpoint")

class CheckpointResponse(BaseModel):
    checkpoints: List[CheckpointItem]

# For Node 2
class CheckpointContent(BaseModel):
    study_material: str = Field(description="Brief study material (approx 300 words)")
    quiz_questions: List[str] = Field(description="Exactly 3 assessment questions")

# Setup LLMs
structure_gen = model.with_structured_output(CheckpointResponse)
content_gen = model.with_structured_output(CheckpointContent)


# --- 3. NODE 1: GENERATE STRUCTURE ---
def generate_structure(state: State):
    report = state['report']
    response = structure_gen.invoke(f"Extract checkpoints from: {report}")
    
    clean_checkpoints = []
    for item in response.checkpoints:
        data = item.model_dump()
        data['id'] = str(uuid.uuid4())
        # Initialize placeholders
        data['study_material'] = "" 
        data['quiz_questions'] = []
        clean_checkpoints.append(data)
        
    return {"checkpoints": clean_checkpoints}


# --- 4. NODE 2: CREATE CONTENT (UPDATED WITH BATCH) ---
def create_content(state: State):
    report = state['report']
    user_req = state['user_request']
    checkpoints = state['checkpoints']
    
    # A. Prepare the list of prompts (Input List)
    batch_prompts = []
    
    for cp in checkpoints:
        prompt = f"""
        Context: {report}
        User Goal: {user_req}
        
        Task: Create content for this checkpoint:
        - Topic: {cp['name']}
        - Objective: {cp['objective']}
        """
        batch_prompts.append(prompt)
    
    # B. Execute Batch (Parallel Processing)
    # The model processes all prompts effectively at the same time
    # Returns a list of CheckpointContent objects
    batch_results = content_gen.batch(batch_prompts)
    
    # C. Map results back to the checkpoints
    # zip() pairs the original checkpoint with its corresponding result
    updated_checkpoints = []
    for cp, result in zip(checkpoints, batch_results):
        cp['study_material'] = result.study_material
        cp['quiz_questions'] = result.quiz_questions
        updated_checkpoints.append(cp)
    
    return {"checkpoints": updated_checkpoints}


# --- 5. GRAPH SETUP ---
builder = StateGraph(State)
builder.add_node("generate_structure", generate_structure)
builder.add_node("create_content", create_content)

builder.add_edge(START, "generate_structure")
builder.add_edge("generate_structure", "create_content")
builder.add_edge("create_content", END)

graph = builder.compile()

# --- 6. EXECUTION ---
inputs = {
    "report": md_text,
    "user_request": "I want to learn best coffee shops in San Francisco."
}

result = graph.invoke(inputs)

# Verify Output
import json
print(json.dumps(result["checkpoints"], indent=2))
# Out:
# [
#   {
#     "name": "Blue Bottle Coffee",
#     "objective": "Focus on single-origin coffee and pour-over methods, known for freshly roasted beans and minimalist aesthetic.",
#     "id": "6f4511ab-0cfa-402d-96f1-40e173666c14",
#     "study_material": "Blue Bottle Coffee, though founded in Oakland in 2002, quickly became a cornerstone of San Francisco's specialty coffee landscape. The brand distinguishes itself through a strong commitment to sourcing and preparation precision. A central focus for Blue Bottle is the use of **single-origin coffee**, meaning their beans are typically sourced from a specific farm or region to highlight unique flavor profiles and the coffee's terroir. To ensure these unique characteristics are fully expressed, Blue Bottle heavily relies on meticulous brewing techniques, most notably **pour-over methods**. This manual process allows for precise control over water temperature and flow, resulting in a clean and defined cup.\r\rThe company is celebrated for its dedication to freshness, emphasizing the use of **freshly roasted beans** to guarantee peak flavor delivery. Beyond the product itself, the Blue Bottle experience is defined by its environment. Their physical locations often feature a **minimalist aesthetic**, characterized by clean lines, simple decor, and an uncluttered space designed to keep the focus squarely on the coffee preparation ritual. In San Francisco, Blue Bottle maintains several key locations, including a popular spot within the historic Ferry Building.",
#     "quiz_questions": [
#       "What specific type of coffee sourcing, which highlights beans from a particular farm or region, is a primary focus for Blue Bottle Coffee?",
#       "Which precise, manual brewing technique is Blue Bottle Coffee known for employing to ensure flavor clarity and extraction?",
#       "Blue Bottle Coffee's physical shop locations are often characterized by what specific design philosophy?"
#     ]
#   },
#   {
#     "name": "Philz Coffee",
#     "objective": "Specializes in custom blended coffee and personalized service, famous for unique blends like 'Tesora'.",
#     "id": "66387cd9-4bb3-410d-9ae6-1d226a027469",
#     "study_material": "Philz Coffee holds a unique and prominent place in the San Francisco coffee landscape, distinguishing itself from the standard espresso-based model. Founded in 2003 by Phil Jaber, Philz originated in the Mission District and has since expanded citywide, becoming a beloved local institution. The core philosophy of Philz revolves around custom blended coffee and highly personalized service. Unlike many third-wave shops that focus purely on single-origin beans and specific brewing methods, Philz specializes in creating unique, proprietary blends of coffee beans. These blends are meticulously crafted to achieve specific flavor profiles and characteristics. The most famous example of these blends is \"Tesora,\" a signature blend that helped cement Philz\u2019s reputation. When ordering at Philz, customers do not order standard lattes or cappuccinos; instead, they choose a blend, and the coffee is prepared one cup at a time using a pour-over method. This ensures maximum freshness and flavor extraction tailored to the customer. Furthermore, the emphasis on personalized service is key. Baristas at Philz are trained to engage with customers, often asking how they prefer their coffee\u2014whether they want cream, sugar, or specific sweetener levels\u2014and then preparing it exactly to their specifications, stirred and ready to drink upon serving. This focus on customization and individual experience sets Philz apart as a pioneer in the personalized coffee movement within the competitive San Francisco market.",
#     "quiz_questions": [
#       "What is the name of the unique, famous coffee blend associated with Philz Coffee?",
#       "Philz Coffee specializes in custom blended coffee and personalized service, but in what year was it founded and where was its original location?",
#       "How does Philz Coffee typically prepare its coffee, setting it apart from shops focused on standard espresso drinks?"
#     ]
#   },
#   {
#     "name": "Sightglass Coffee",
#     "objective": "Third-wave coffee shop emphasizing roasting transparency, known for its large roastery with viewing windows.",
#     "id": "220a4934-9750-409c-9620-d42ec92fbcd9",
#     "study_material": "Sightglass Coffee, founded in 2009, quickly established itself as a key player in San Francisco's competitive coffee scene, firmly embracing the principles of the third-wave coffee movement. This movement emphasizes high-quality, single-origin beans, sophisticated brewing techniques, and a deep appreciation for the entire coffee supply chain. Sightglass is particularly noted for its commitment to roasting transparency. Unlike many smaller cafes, Sightglass operates a large, impressive roastery located in the SOMA district. This flagship location is designed with an industrial aesthetic and features prominent viewing windows, allowing customers to observe the entire roasting process firsthand. This commitment to visibility ensures customers understand the care and precision involved in turning green coffee beans into the final roasted product. The SOMA roastery serves not only as a production facility but also as a community hub, offering a unique educational experience alongside expertly prepared beverages.",
#     "quiz_questions": [
#       "Sightglass Coffee is most strongly associated with which major movement in the coffee industry that focuses on quality and supply chain appreciation?",
#       "What specific architectural feature of the Sightglass flagship location is highlighted for promoting 'roasting transparency'?",
#       "In which San Francisco district is the Sightglass Coffee flagship roastery primarily located?"
#     ]
#   },
#   {
#     "name": "Ritual Coffee Roasters",
#     "objective": "Pioneer in the third-wave movement, focusing on direct trade relationships and seasonal coffee offerings.",
#     "id": "95d52b93-4870-4c37-9ad2-e03c473fa074",
#     "study_material": "Ritual Coffee Roasters, founded in 2005, is widely recognized as a foundational pioneer of the third-wave coffee movement in San Francisco. This movement focuses on treating coffee as an artisan product, emphasizing high quality, sustainable sourcing, and superior preparation methods. Ritual played a crucial role in establishing these elevated standards throughout the Bay Area. A cornerstone of Ritual's business model is its deep commitment to direct trade relationships. By engaging directly with coffee producers, they ensure greater transparency across the supply chain. This practice allows Ritual to pay premium prices directly to farmers, fostering sustainability and securing access to the highest quality, most ethically sourced green coffee beans available. This direct connection also enables a deeper understanding of the coffee's origin and characteristics. Furthermore, Ritual emphasizes seasonal offerings. Recognizing that coffee is a seasonal crop, they rotate their menu according to global harvest cycles. This dedication to seasonality ensures that the beans they roast are always at their freshest and most flavorful peak, defining the distinct and high-quality experience offered at their various San Francisco locations, including those in the Castro and Mission districts.",
#     "quiz_questions": [
#       "What specific coffee culture movement is Ritual Coffee Roasters considered a pioneer of in San Francisco?",
#       "What sourcing practice does Ritual Coffee Roasters prioritize to ensure transparency and support farmers directly?",
#       "Why does Ritual Coffee Roasters focus heavily on providing seasonal coffee offerings?"
#     ]
#   },
#   {
#     "name": "Four Barrel Coffee",
#     "objective": "Known for small-batch roasting and community focus, a local institution in the Mission District.",
#     "id": "313374a9-4fa6-42c9-8a20-840516ddcda0",
#     "study_material": "Four Barrel Coffee, established in 2008, quickly cemented its status as a cornerstone of the Mission District's vibrant culinary and coffee scene. While shops like Blue Bottle focus on minimalist aesthetics and pour-overs, and Philz emphasizes personalized custom blends, Four Barrel distinguishes itself through its dedication to small-batch roasting and a strong community focus. This approach ensures high quality control over their beans while fostering a deep connection with local patrons. The establishment is famously known for its flagship location on Valencia Street in the Mission District, which has become recognized as a local institution. Unlike the large, transparent roastery of Sightglass in SOMA, Four Barrel creates an intimate yet bustling environment where coffee preparation is central. Four Barrel emerged slightly later than pioneers like Ritual Coffee Roasters (2005) but still played a significant role in the ongoing evolution of San Francisco's third-wave coffee movement. Their commitment to quality sourcing, careful roasting processes, and maintaining a neighborhood hub underscores their objective: delivering exceptional coffee while being deeply embedded in the local culture. This focus on small-scale production and local engagement contrasts with the city-wide expansion strategies adopted by larger chains like Blue Bottle and Philz, allowing Four Barrel to maintain its unique, neighborhood-centric identity.",
#     "quiz_questions": [
#       "In what year was Four Barrel Coffee established?",
#       "What specific roasting technique does Four Barrel Coffee utilize, distinguishing it from larger coffee chains?",
#       "Four Barrel Coffee is known as a local institution in which specific San Francisco neighborhood?"
#     ]
#   }
# ]

# %%
result
# Out:
# {'report': 'Python uses indentation. Lists are mutable. Dictionaries are key-value pairs.',
#  'user_request': 'I want to learn python basics',
#  'checkpoints': [{'name': 'Python Syntax',
#    'objective': 'Understand that Python uses indentation for code structure.',
#    'id': '34561e89-8f15-484d-bf77-d0c4214b63e9',
#    'study_material': "Unlike languages that use curly braces ({}) to define blocks of code, Python uses indentation. Indentation is mandatory and defines the logical structure of the program, marking which lines belong to conditional statements (like 'if'), loops ('for', 'while'), or functions. Standard Python convention dictates using exactly four spaces for each level of indentation. Mixing tabs and spaces or using inconsistent indentation levels within the same block will result in an 'IndentationError' or 'TabError'. This strict requirement enforces clean, readable code, making indentation a critical part of Python's syntax.",
#    'quiz_questions': ['What is the primary role of indentation in Python programming?',
#     'What is the recommended standard number of spaces for a single level of indentation in Python?',
#     'What type of error occurs if a Python program has inconsistent indentation within a single code block?']},
#   {'name': 'List Properties',
#    'objective': 'Know that lists are mutable data structures.',
#    'id': 'f810cfc4-15d2-4f29-87c6-6136b1dcf991',
#    'study_material': "Python lists are ordered, changeable collections of items. The most important property discussed here is *mutability*. A mutable data structure is one whose contents can be modified after it has been created. For lists, this means you can add elements (using `append()` or `insert()`), remove elements (using `pop()` or `remove()`), or change the value of an existing element by referencing its index (e.g., `my_list[0] = 'new_value'`). This ability to modify the list in place distinguishes lists from immutable structures like strings and tuples, where any change results in the creation of a completely new object.",
#    'quiz_questions': ['What does it mean for a Python list to be a mutable data structure?',
#     "If you have a list `L = [1, 2, 3]`, what operation or method allows you to change the value '2' to '5'?",
#     'Name one common Python data structure that is immutable, contrasting it with a list.']},
#   {'name': 'Dictionary Structure',
#    'objective': 'Recognize that dictionaries store data as key-value pairs.',
#    'id': '3c365b7d-a312-4259-84d0-6163d4910548',
#    'study_material': "Python dictionaries (often called 'dicts') are unordered collections used to store data values like a map. The fundamental structure of a dictionary is based on **key-value pairs**. Each pair links a unique key to a specific value using a colon (:), and pairs are separated by commas. Keys act as identifiers for retrieving data, similar to an index, but they must be unique and immutable data types (like strings or numbers). Values, however, can be any Python object, including mutable types like lists or other dictionaries. This structure allows for highly efficient retrieval of values using the associated key. Example: {'product_id': 101, 'price': 45.99}.",
#    'quiz_questions': ['What is the fundamental unit of data storage in a Python dictionary?',
#     'In the structure of a dictionary pair, what symbol separates the key from its value?',
#     'True or False: Dictionary keys must be unique.']}]}
